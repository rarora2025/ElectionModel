# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
economic_df = pd.read_csv("update_economics.csv")
president_df = pd.read_csv("presidentupdated.csv")
president_df = president_df.reset_index(drop=True)
economic_df = economic_df.reset_index(drop=True)

# %%
president_df
# Out:
#     Year            Candidate 1       Candidate 2 Candidate 1 Party  \
# 0   2020              Joe Biden      Donald Trump          Democrat
# 1   2016           Donald Trump   Hillary Clinton        Republican
# 2   2012           Barack Obama       Mitt Romney          Democrat
# 3   2008           Barack Obama       John McCain          Democrat
# 4   2004         George W. Bush        John Kerry        Republican
# 5   2000         George W. Bush           Al Gore        Republican
# 6   1996           Bill Clinton          Bob Dole          Democrat
# 7   1992           Bill Clinton  George H.W. Bush          Democrat
# 8   1988       George H.W. Bush   Michael Dukakis        Republican
# 9   1984          Ronald Reagan    Walter Mondale        Republican
# 10  1980          Ronald Reagan      Jimmy Carter        Republican
# 11  1976           Jimmy Carter       Gerald Ford          Democrat
# 12  1972          Richard Nixon   George McGovern        Republican
# 13  1968          Richard Nixon   Hubert Humphrey        Republican
# 14  1964      Lyndon B. Johnson   Barry Goldwater          Democrat
# 15  1960        John F. Kennedy     Richard Nixon          Democrat
# 16  1956   Dwight D. Eisenhower   Adlai Stevenson        Republican
# 17  1952   Dwight D. Eisenhower   Adlai Stevenson        Republican
# 18  1948        Harry S. Truman   Thomas E. Dewey          Democrat
# 19  1944  Franklin D. Roosevelt   Thomas E. Dewey          Democrat
# 20  1940  Franklin D. Roosevelt   Wendell Willkie          Democrat
# 21  1936  Franklin D. Roosevelt        Alf Landon          Democrat
# 22  1932  Franklin D. Roosevelt    Herbert Hoover          Democrat
#
#    Candidate 2 Party  Electoral Votes Candidate 1  \
# 0         Republican                          306
# 1           Democrat                          304
# 2         Republican                          332
# 3         Republican                          365
# 4           Democrat                          286
# 5           Democrat                          271
# 6         Republican                          379
# 7         Republican                          370
# 8           Democrat                          426
# 9           Democrat                          525
# 10          Democrat                          489
# 11        Republican                          297
# 12          Democrat                          520
# 13          Democrat                          301
# 14        Republican                          486
# 15        Republican                          303
# 16          Democrat                          457
# 17          Democrat                          442
# 18        Republican                          303
# 19        Republican                          432
# 20        Republican                          449
# 21        Republican                          523
# 22        Republican                          472
#
#     Electoral Votes Candidate 2 Total Votes Candidate 1  \
# 0                           232              81,283,098
# 1                           227              62,984,828
# 2                           206              62,615,406
# 3                           173              66,862,039
# 4                           251              62,040,610
# 5                           266              50,460,110
# 6                           159              47,400,125
# 7                           168              44,909,806
# 8                           111              48,886,597
# 9                            13              54,455,472
# 10                           49              43,903,230
# 11                          240              40,831,881
# 12                           17              47,168,710
# 13                          191              31,783,783
# 14                           52              43,127,041
# 15                          219              34,220,984
# 16                           73              35,579,180
# 17                           89              34,075,529
# 18                          189              24,179,347
# 19                           99              25,612,916
# 20                           82              27,313,945
# 21                            8              27,752,648
# 22                           59              22,821,277
#
#    Total Votes Candidate 2
# 0               74,222,958
# 1               65,853,514
# 2               59,142,004
# 3               58,319,442
# 4               59,028,111
# 5               51,003,926
# 6               39,198,755
# 7               39,104,550
# 8               41,809,476
# 9               37,577,352
# 10              35,480,115
# 11              39,148,634
# 12              17,995,488
# 13                 511,944
# 14              17,951,287
# 15                 112,827
# 16               9,551,152
# 17               6,700,439
# 18               2,188,055
# 19               3,594,987
# 20               4,966,201
# 21              11,070,786
# 22               7,060,023

# %%
economic_df
# Out:
#       Year Inflation Rate Change Federal Funds Rate Federal Funds Rate  \
# 0      NaN            NaN                       NaN                NaN
# 1      NaN            NaN                       NaN                NaN
# 2   1929.0          0.60%                     0.00%              0.00%
# 3   1930.0         -6.40%                     0.00%              0.00%
# 4   1931.0         -9.30%                     0.00%              0.00%
# ..     ...            ...                       ...                ...
# 89  2016.0          2.10%                    50.00%              0.75%
# 90  2017.0          2.10%                   100.00%              1.50%
# 91  2018.0          1.90%                    66.67%              2.50%
# 92  2019.0          2.30%                   -30.00%              1.75%
# 93  2020.0          1.40%                   -85.71%              0.25%
#
#    GDP % Growth Unemployment Rate Change Unemployment Rate  \
# 0           NaN               NaN                      NaN
# 1           NaN               NaN                      NaN
# 2         0.00%             3.20%                   -5.00%
# 3        -8.50%             8.70%                  171.88%
# 4        -6.40%            15.90%                   82.76%
# ..          ...               ...                      ...
# 89        1.70%             4.70%                   -6.00%
# 90        2.30%             4.10%                  -12.77%
# 91        2.90%             3.90%                   -4.88%
# 92        2.30%             3.60%                   -7.69%
# 93       -3.40%             6.70%                   86.11%
#
#    Adjusted Oil Prices ($/barrel) Change in Oil Change in S&P  \
# 0                             NaN           NaN           NaN
# 1                             NaN           NaN           NaN
# 2                          $24.03            0%       -11.91%
# 3                          $24.03            0%       -28.48%
# 4                          $24.03            0%       -47.07%
# ..                            ...           ...           ...
# 89                         $44.21          -14%         9.54%
# 90                         $52.42           19%        19.42%
# 91                         $67.24           28%        -6.24%
# 92                         $57.17          -15%        28.88%
# 93                         $36.39          -36%        16.26%
#
#    Change in Balance of Trade
# 0                         NaN
# 1                         NaN
# 2                       0.00%
# 3                       0.00%
# 4                       0.00%
# ..                        ...
# 89                        -6%
# 90                         2%
# 91                         5%
# 92                         0%
# 93                         0%
#
# [94 rows x 11 columns]

# %%
economic_df = economic_df.reset_index(drop=True)
#for i in range(len(economic_df)):
    #year = economic_df.iloc[[i]]["Year"][i]
    
    #if(year%4 != 0):
        #print(year)
        #economic_df=economic_df.drop(economic_df.index[i])
        
        
economic_df = economic_df[economic_df['Year']%4==0]
economic_df = economic_df.reset_index(drop=True)
economic_df
# Out:
#       Year Inflation Rate Change Federal Funds Rate Federal Funds Rate  \
# 0   1932.0        -10.30%                     0.00%              0.00%
# 1   1936.0          1.40%                     0.00%              0.00%
# 2   1940.0          0.70%                     0.00%              0.00%
# 3   1944.0          2.30%                     0.00%              0.00%
# 4   1948.0          3.00%                     0.00%              0.00%
# 5   1952.0          0.80%                     0.00%              0.00%
# 6   1956.0          3.00%                    20.00%              3.00%
# 7   1960.0          1.40%                   -50.00%              2.00%
# 8   1964.0          1.00%                     7.14%              3.75%
# 9   1968.0          4.70%                    33.33%              6.00%
# 10  1972.0          3.40%                    15.00%              5.75%
# 11  1976.0          4.90%                     0.00%              4.75%
# 12  1980.0         12.50%                    50.00%             18.00%
# 13  1984.0          3.90%                   -10.81%              8.25%
# 14  1988.0          4.40%                    44.44%              9.75%
# 15  1992.0          2.90%                   -25.00%              3.00%
# 16  1996.0          3.30%                    -4.55%              5.25%
# 17  2000.0          3.40%                    18.18%              6.50%
# 18  2004.0          3.30%                   125.00%              2.25%
# 19  2008.0          0.10%                   -94.12%              0.25%
# 20  2012.0          1.70%                     0.00%              0.25%
# 21  2016.0          2.10%                    50.00%              0.75%
# 22  2020.0          1.40%                   -85.71%              0.25%
#
#    GDP % Growth Unemployment Rate Change Unemployment Rate  \
# 0       -12.90%            23.60%                   48.43%
# 1        12.90%            16.90%                  -15.92%
# 2         8.80%            14.60%                  -15.12%
# 3         8.00%             1.20%                  -36.84%
# 4         4.10%             4.00%                   11.11%
# 5         4.10%             2.70%                  -12.90%
# 6         2.10%             4.20%                    0.00%
# 7         2.60%             6.60%                   24.53%
# 8         5.80%             5.00%                   -9.09%
# 9         4.90%             3.40%                  -10.53%
# 10        5.30%             5.20%                  -13.33%
# 11        5.40%             7.80%                   -4.88%
# 12       -0.30%             7.20%                   20.00%
# 13        7.20%             7.30%                  -12.05%
# 14        4.20%             5.30%                   -7.02%
# 15        3.50%             7.40%                    1.37%
# 16        3.80%             5.40%                   -3.57%
# 17        4.10%             3.90%                   -2.50%
# 18        3.90%             5.40%                   -5.26%
# 19        0.10%             7.30%                   46.00%
# 20        2.30%             7.90%                   -7.06%
# 21        1.70%             4.70%                   -6.00%
# 22       -3.40%             6.70%                   86.11%
#
#    Adjusted Oil Prices ($/barrel) Change in Oil Change in S&P  \
# 0                          $24.03            0%       -15.15%
# 1                          $24.03            0%        27.92%
# 2                          $24.03            0%       -15.29%
# 3                          $24.03            0%        13.80%
# 4                          $33.69           19%        -0.65%
# 5                          $30.50           -2%        11.78%
# 6                          $31.64           -1%         2.62%
# 7                          $28.79           -4%        -2.97%
# 8                          $28.27            2%        12.97%
# 9                          $26.68           -2%         7.66%
# 10                         $25.17           -3%        15.63%
# 11                         $67.30            2%        19.15%
# 12                        $132.90           33%        25.77%
# 13                         $80.91           -5%         1.40%
# 14                         $36.80          -19%        12.40%
# 15                         $40.10           -8%         4.46%
# 16                         $38.11           19%        20.26%
# 17                         $46.47           60%       -10.14%
# 18                         $58.23           32%         8.99%
# 19                        $123.79           37%       -38.49%
# 20                        $110.09           -3%        13.41%
# 21                         $44.21          -14%         9.54%
# 22                         $36.39          -36%        16.26%
#
#    Change in Balance of Trade
# 0                       0.00%
# 1                       0.00%
# 2                       0.00%
# 3                       0.00%
# 4                       0.00%
# 5                       0.00%
# 6                       0.00%
# 7                       0.00%
# 8                       0.00%
# 9                       0.00%
# 10                      0.00%
# 11                       -89%
# 12                       -47%
# 13                        79%
# 14                       -30%
# 15                        15%
# 16                         2%
# 17                        38%
# 18                        14%
# 19                        -1%
# 20                        -9%
# 21                        -6%
# 22                         0%

# %%
june_gallup = [60,60,60,60,60,31.5,72,59,74,41,57.5,45.0, 33.6, 54.0, 50.0, 37.3, 55.0, 57.5, 48.5, 29.0, 46.4, 51.6, 38]


economic_df['June Gallup'] = june_gallup

economic_df
# Out:
#       Year Inflation Rate Change Federal Funds Rate Federal Funds Rate  \
# 0   1932.0        -10.30%                     0.00%              0.00%
# 1   1936.0          1.40%                     0.00%              0.00%
# 2   1940.0          0.70%                     0.00%              0.00%
# 3   1944.0          2.30%                     0.00%              0.00%
# 4   1948.0          3.00%                     0.00%              0.00%
# 5   1952.0          0.80%                     0.00%              0.00%
# 6   1956.0          3.00%                    20.00%              3.00%
# 7   1960.0          1.40%                   -50.00%              2.00%
# 8   1964.0          1.00%                     7.14%              3.75%
# 9   1968.0          4.70%                    33.33%              6.00%
# 10  1972.0          3.40%                    15.00%              5.75%
# 11  1976.0          4.90%                     0.00%              4.75%
# 12  1980.0         12.50%                    50.00%             18.00%
# 13  1984.0          3.90%                   -10.81%              8.25%
# 14  1988.0          4.40%                    44.44%              9.75%
# 15  1992.0          2.90%                   -25.00%              3.00%
# 16  1996.0          3.30%                    -4.55%              5.25%
# 17  2000.0          3.40%                    18.18%              6.50%
# 18  2004.0          3.30%                   125.00%              2.25%
# 19  2008.0          0.10%                   -94.12%              0.25%
# 20  2012.0          1.70%                     0.00%              0.25%
# 21  2016.0          2.10%                    50.00%              0.75%
# 22  2020.0          1.40%                   -85.71%              0.25%
#
#    GDP % Growth Unemployment Rate Change Unemployment Rate  \
# 0       -12.90%            23.60%                   48.43%
# 1        12.90%            16.90%                  -15.92%
# 2         8.80%            14.60%                  -15.12%
# 3         8.00%             1.20%                  -36.84%
# 4         4.10%             4.00%                   11.11%
# 5         4.10%             2.70%                  -12.90%
# 6         2.10%             4.20%                    0.00%
# 7         2.60%             6.60%                   24.53%
# 8         5.80%             5.00%                   -9.09%
# 9         4.90%             3.40%                  -10.53%
# 10        5.30%             5.20%                  -13.33%
# 11        5.40%             7.80%                   -4.88%
# 12       -0.30%             7.20%                   20.00%
# 13        7.20%             7.30%                  -12.05%
# 14        4.20%             5.30%                   -7.02%
# 15        3.50%             7.40%                    1.37%
# 16        3.80%             5.40%                   -3.57%
# 17        4.10%             3.90%                   -2.50%
# 18        3.90%             5.40%                   -5.26%
# 19        0.10%             7.30%                   46.00%
# 20        2.30%             7.90%                   -7.06%
# 21        1.70%             4.70%                   -6.00%
# 22       -3.40%             6.70%                   86.11%
#
#    Adjusted Oil Prices ($/barrel) Change in Oil Change in S&P  \
# 0                          $24.03            0%       -15.15%
# 1                          $24.03            0%        27.92%
# 2                          $24.03            0%       -15.29%
# 3                          $24.03            0%        13.80%
# 4                          $33.69           19%        -0.65%
# 5                          $30.50           -2%        11.78%
# 6                          $31.64           -1%         2.62%
# 7                          $28.79           -4%        -2.97%
# 8                          $28.27            2%        12.97%
# 9                          $26.68           -2%         7.66%
# 10                         $25.17           -3%        15.63%
# 11                         $67.30            2%        19.15%
# 12                        $132.90           33%        25.77%
# 13                         $80.91           -5%         1.40%
# 14                         $36.80          -19%        12.40%
# 15                         $40.10           -8%         4.46%
# 16                         $38.11           19%        20.26%
# 17                         $46.47           60%       -10.14%
# 18                         $58.23           32%         8.99%
# 19                        $123.79           37%       -38.49%
# 20                        $110.09           -3%        13.41%
# 21                         $44.21          -14%         9.54%
# 22                         $36.39          -36%        16.26%
#
#    Change in Balance of Trade  June Gallup
# 0                       0.00%         60.0
# 1                       0.00%         60.0
# 2                       0.00%         60.0
# 3                       0.00%         60.0
# 4                       0.00%         60.0
# 5                       0.00%         31.5
# 6                       0.00%         72.0
# 7                       0.00%         59.0
# 8                       0.00%         74.0
# 9                       0.00%         41.0
# 10                      0.00%         57.5
# 11                       -89%         45.0
# 12                       -47%         33.6
# 13                        79%         54.0
# 14                       -30%         50.0
# 15                        15%         37.3
# 16                         2%         55.0
# 17                        38%         57.5
# 18                        14%         48.5
# 19                        -1%         29.0
# 20                        -9%         46.4
# 21                        -6%         51.6
# 22                         0%         38.0

# %%
economic_df['Inflation Rate'] = economic_df['Inflation Rate'].str.rstrip("%").astype(float)
economic_df['Change Federal Funds Rate'] = economic_df['Change Federal Funds Rate'].str.rstrip("%").astype(float)
economic_df['Federal Funds Rate'] = economic_df['Federal Funds Rate'].str.rstrip("%").astype(float)
economic_df['GDP % Growth'] = economic_df['GDP % Growth'].str.rstrip("%").astype(float)
economic_df['Unemployment Rate'] = economic_df['Unemployment Rate'].str.rstrip("%").astype(float)
economic_df['Change Unemployment Rate'] = economic_df['Change Unemployment Rate'].str.rstrip("%").astype(float)
economic_df['Change in Oil'] = economic_df['Change in Oil'].str.rstrip("%").astype(float)
economic_df['Change in S&P'] = economic_df['Change in S&P'].str.rstrip("%").astype(float)
economic_df['Change in Balance of Trade'] = economic_df['Change in Balance of Trade'].str.rstrip("%").astype(float)

economic_df
# Out:
#       Year  Inflation Rate  Change Federal Funds Rate  Federal Funds Rate  \
# 0   1932.0           -10.3                       0.00                0.00
# 1   1936.0             1.4                       0.00                0.00
# 2   1940.0             0.7                       0.00                0.00
# 3   1944.0             2.3                       0.00                0.00
# 4   1948.0             3.0                       0.00                0.00
# 5   1952.0             0.8                       0.00                0.00
# 6   1956.0             3.0                      20.00                3.00
# 7   1960.0             1.4                     -50.00                2.00
# 8   1964.0             1.0                       7.14                3.75
# 9   1968.0             4.7                      33.33                6.00
# 10  1972.0             3.4                      15.00                5.75
# 11  1976.0             4.9                       0.00                4.75
# 12  1980.0            12.5                      50.00               18.00
# 13  1984.0             3.9                     -10.81                8.25
# 14  1988.0             4.4                      44.44                9.75
# 15  1992.0             2.9                     -25.00                3.00
# 16  1996.0             3.3                      -4.55                5.25
# 17  2000.0             3.4                      18.18                6.50
# 18  2004.0             3.3                     125.00                2.25
# 19  2008.0             0.1                     -94.12                0.25
# 20  2012.0             1.7                       0.00                0.25
# 21  2016.0             2.1                      50.00                0.75
# 22  2020.0             1.4                     -85.71                0.25
#
#     GDP % Growth  Unemployment Rate  Change Unemployment Rate  \
# 0          -12.9               23.6                     48.43
# 1           12.9               16.9                    -15.92
# 2            8.8               14.6                    -15.12
# 3            8.0                1.2                    -36.84
# 4            4.1                4.0                     11.11
# 5            4.1                2.7                    -12.90
# 6            2.1                4.2                      0.00
# 7            2.6                6.6                     24.53
# 8            5.8                5.0                     -9.09
# 9            4.9                3.4                    -10.53
# 10           5.3                5.2                    -13.33
# 11           5.4                7.8                     -4.88
# 12          -0.3                7.2                     20.00
# 13           7.2                7.3                    -12.05
# 14           4.2                5.3                     -7.02
# 15           3.5                7.4                      1.37
# 16           3.8                5.4                     -3.57
# 17           4.1                3.9                     -2.50
# 18           3.9                5.4                     -5.26
# 19           0.1                7.3                     46.00
# 20           2.3                7.9                     -7.06
# 21           1.7                4.7                     -6.00
# 22          -3.4                6.7                     86.11
#
#    Adjusted Oil Prices ($/barrel)  Change in Oil  Change in S&P  \
# 0                          $24.03            0.0         -15.15
# 1                          $24.03            0.0          27.92
# 2                          $24.03            0.0         -15.29
# 3                          $24.03            0.0          13.80
# 4                          $33.69           19.0          -0.65
# 5                          $30.50           -2.0          11.78
# 6                          $31.64           -1.0           2.62
# 7                          $28.79           -4.0          -2.97
# 8                          $28.27            2.0          12.97
# 9                          $26.68           -2.0           7.66
# 10                         $25.17           -3.0          15.63
# 11                         $67.30            2.0          19.15
# 12                        $132.90           33.0          25.77
# 13                         $80.91           -5.0           1.40
# 14                         $36.80          -19.0          12.40
# 15                         $40.10           -8.0           4.46
# 16                         $38.11           19.0          20.26
# 17                         $46.47           60.0         -10.14
# 18                         $58.23           32.0           8.99
# 19                        $123.79           37.0         -38.49
# 20                        $110.09           -3.0          13.41
# 21                         $44.21          -14.0           9.54
# 22                         $36.39          -36.0          16.26
#
#     Change in Balance of Trade  June Gallup
# 0                          0.0         60.0
# 1                          0.0         60.0
# 2                          0.0         60.0
# 3                          0.0         60.0
# 4                          0.0         60.0
# 5                          0.0         31.5
# 6                          0.0         72.0
# 7                          0.0         59.0
# 8                          0.0         74.0
# 9                          0.0         41.0
# 10                         0.0         57.5
# 11                       -89.0         45.0
# 12                       -47.0         33.6
# 13                        79.0         54.0
# 14                       -30.0         50.0
# 15                        15.0         37.3
# 16                         2.0         55.0
# 17                        38.0         57.5
# 18                        14.0         48.5
# 19                        -1.0         29.0
# 20                        -9.0         46.4
# 21                        -6.0         51.6
# 22                         0.0         38.0

# %%
for x in range(11):
    president_df=president_df.drop(president_df.index[0])

# %%
for x in range(11):
    economic_df=economic_df.drop(economic_df.index[len(economic_df)-1])

# %%
president_df
# Out:
#     Year            Candidate 1      Candidate 2 Candidate 1 Party  \
# 11  1976           Jimmy Carter      Gerald Ford          Democrat
# 12  1972          Richard Nixon  George McGovern        Republican
# 13  1968          Richard Nixon  Hubert Humphrey        Republican
# 14  1964      Lyndon B. Johnson  Barry Goldwater          Democrat
# 15  1960        John F. Kennedy    Richard Nixon          Democrat
# 16  1956   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 17  1952   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 18  1948        Harry S. Truman  Thomas E. Dewey          Democrat
# 19  1944  Franklin D. Roosevelt  Thomas E. Dewey          Democrat
# 20  1940  Franklin D. Roosevelt  Wendell Willkie          Democrat
# 21  1936  Franklin D. Roosevelt       Alf Landon          Democrat
# 22  1932  Franklin D. Roosevelt   Herbert Hoover          Democrat
#
#    Candidate 2 Party  Electoral Votes Candidate 1  \
# 11        Republican                          297
# 12          Democrat                          520
# 13          Democrat                          301
# 14        Republican                          486
# 15        Republican                          303
# 16          Democrat                          457
# 17          Democrat                          442
# 18        Republican                          303
# 19        Republican                          432
# 20        Republican                          449
# 21        Republican                          523
# 22        Republican                          472
#
#     Electoral Votes Candidate 2 Total Votes Candidate 1  \
# 11                          240              40,831,881
# 12                           17              47,168,710
# 13                          191              31,783,783
# 14                           52              43,127,041
# 15                          219              34,220,984
# 16                           73              35,579,180
# 17                           89              34,075,529
# 18                          189              24,179,347
# 19                           99              25,612,916
# 20                           82              27,313,945
# 21                            8              27,752,648
# 22                           59              22,821,277
#
#    Total Votes Candidate 2
# 11              39,148,634
# 12              17,995,488
# 13                 511,944
# 14              17,951,287
# 15                 112,827
# 16               9,551,152
# 17               6,700,439
# 18               2,188,055
# 19               3,594,987
# 20               4,966,201
# 21              11,070,786
# 22               7,060,023

# %%
economic_df
# Out:
#       Year  Inflation Rate  Change Federal Funds Rate  Federal Funds Rate  \
# 0   1932.0           -10.3                       0.00                0.00
# 1   1936.0             1.4                       0.00                0.00
# 2   1940.0             0.7                       0.00                0.00
# 3   1944.0             2.3                       0.00                0.00
# 4   1948.0             3.0                       0.00                0.00
# 5   1952.0             0.8                       0.00                0.00
# 6   1956.0             3.0                      20.00                3.00
# 7   1960.0             1.4                     -50.00                2.00
# 8   1964.0             1.0                       7.14                3.75
# 9   1968.0             4.7                      33.33                6.00
# 10  1972.0             3.4                      15.00                5.75
# 11  1976.0             4.9                       0.00                4.75
#
#     GDP % Growth  Unemployment Rate  Change Unemployment Rate  \
# 0          -12.9               23.6                     48.43
# 1           12.9               16.9                    -15.92
# 2            8.8               14.6                    -15.12
# 3            8.0                1.2                    -36.84
# 4            4.1                4.0                     11.11
# 5            4.1                2.7                    -12.90
# 6            2.1                4.2                      0.00
# 7            2.6                6.6                     24.53
# 8            5.8                5.0                     -9.09
# 9            4.9                3.4                    -10.53
# 10           5.3                5.2                    -13.33
# 11           5.4                7.8                     -4.88
#
#    Adjusted Oil Prices ($/barrel)  Change in Oil  Change in S&P  \
# 0                          $24.03            0.0         -15.15
# 1                          $24.03            0.0          27.92
# 2                          $24.03            0.0         -15.29
# 3                          $24.03            0.0          13.80
# 4                          $33.69           19.0          -0.65
# 5                          $30.50           -2.0          11.78
# 6                          $31.64           -1.0           2.62
# 7                          $28.79           -4.0          -2.97
# 8                          $28.27            2.0          12.97
# 9                          $26.68           -2.0           7.66
# 10                         $25.17           -3.0          15.63
# 11                         $67.30            2.0          19.15
#
#     Change in Balance of Trade  June Gallup
# 0                          0.0         60.0
# 1                          0.0         60.0
# 2                          0.0         60.0
# 3                          0.0         60.0
# 4                          0.0         60.0
# 5                          0.0         31.5
# 6                          0.0         72.0
# 7                          0.0         59.0
# 8                          0.0         74.0
# 9                          0.0         41.0
# 10                         0.0         57.5
# 11                       -89.0         45.0

# %%
for column in economic_df:
    president_df[column] = economic_df[column].tolist()

# %%
president_df
# Out:
#       Year            Candidate 1      Candidate 2 Candidate 1 Party  \
# 11  1932.0           Jimmy Carter      Gerald Ford          Democrat
# 12  1936.0          Richard Nixon  George McGovern        Republican
# 13  1940.0          Richard Nixon  Hubert Humphrey        Republican
# 14  1944.0      Lyndon B. Johnson  Barry Goldwater          Democrat
# 15  1948.0        John F. Kennedy    Richard Nixon          Democrat
# 16  1952.0   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 17  1956.0   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 18  1960.0        Harry S. Truman  Thomas E. Dewey          Democrat
# 19  1964.0  Franklin D. Roosevelt  Thomas E. Dewey          Democrat
# 20  1968.0  Franklin D. Roosevelt  Wendell Willkie          Democrat
# 21  1972.0  Franklin D. Roosevelt       Alf Landon          Democrat
# 22  1976.0  Franklin D. Roosevelt   Herbert Hoover          Democrat
#
#    Candidate 2 Party  Electoral Votes Candidate 1  \
# 11        Republican                          297
# 12          Democrat                          520
# 13          Democrat                          301
# 14        Republican                          486
# 15        Republican                          303
# 16          Democrat                          457
# 17          Democrat                          442
# 18        Republican                          303
# 19        Republican                          432
# 20        Republican                          449
# 21        Republican                          523
# 22        Republican                          472
#
#     Electoral Votes Candidate 2 Total Votes Candidate 1  \
# 11                          240              40,831,881
# 12                           17              47,168,710
# 13                          191              31,783,783
# 14                           52              43,127,041
# 15                          219              34,220,984
# 16                           73              35,579,180
# 17                           89              34,075,529
# 18                          189              24,179,347
# 19                           99              25,612,916
# 20                           82              27,313,945
# 21                            8              27,752,648
# 22                           59              22,821,277
#
#    Total Votes Candidate 2  Inflation Rate  Change Federal Funds Rate  \
# 11              39,148,634           -10.3                       0.00
# 12              17,995,488             1.4                       0.00
# 13                 511,944             0.7                       0.00
# 14              17,951,287             2.3                       0.00
# 15                 112,827             3.0                       0.00
# 16               9,551,152             0.8                       0.00
# 17               6,700,439             3.0                      20.00
# 18               2,188,055             1.4                     -50.00
# 19               3,594,987             1.0                       7.14
# 20               4,966,201             4.7                      33.33
# 21              11,070,786             3.4                      15.00
# 22               7,060,023             4.9                       0.00
#
#     Federal Funds Rate  GDP % Growth  Unemployment Rate  \
# 11                0.00         -12.9               23.6
# 12                0.00          12.9               16.9
# 13                0.00           8.8               14.6
# 14                0.00           8.0                1.2
# 15                0.00           4.1                4.0
# 16                0.00           4.1                2.7
# 17                3.00           2.1                4.2
# 18                2.00           2.6                6.6
# 19                3.75           5.8                5.0
# 20                6.00           4.9                3.4
# 21                5.75           5.3                5.2
# 22                4.75           5.4                7.8
#
#     Change Unemployment Rate Adjusted Oil Prices ($/barrel)  Change in Oil  \
# 11                     48.43                         $24.03            0.0
# 12                    -15.92                         $24.03            0.0
# 13                    -15.12                         $24.03            0.0
# 14                    -36.84                         $24.03            0.0
# 15                     11.11                         $33.69           19.0
# 16                    -12.90                         $30.50           -2.0
# 17                      0.00                         $31.64           -1.0
# 18                     24.53                         $28.79           -4.0
# 19                     -9.09                         $28.27            2.0
# 20                    -10.53                         $26.68           -2.0
# 21                    -13.33                         $25.17           -3.0
# 22                     -4.88                         $67.30            2.0
#
#     Change in S&P  Change in Balance of Trade  June Gallup
# 11         -15.15                         0.0         60.0
# 12          27.92                         0.0         60.0
# 13         -15.29                         0.0         60.0
# 14          13.80                         0.0         60.0
# 15          -0.65                         0.0         60.0
# 16          11.78                         0.0         31.5
# 17           2.62                         0.0         72.0
# 18          -2.97                         0.0         59.0
# 19          12.97                         0.0         74.0
# 20           7.66                         0.0         41.0
# 21          15.63                         0.0         57.5
# 22          19.15                       -89.0         45.0

# %%
del president_df["Change in Oil"]
del president_df["Change Federal Funds Rate"]
del president_df["Change in Balance of Trade"]
del president_df["Federal Funds Rate"]

# %%
president_df
# Out:
#       Year            Candidate 1      Candidate 2 Candidate 1 Party  \
# 11  1932.0           Jimmy Carter      Gerald Ford          Democrat
# 12  1936.0          Richard Nixon  George McGovern        Republican
# 13  1940.0          Richard Nixon  Hubert Humphrey        Republican
# 14  1944.0      Lyndon B. Johnson  Barry Goldwater          Democrat
# 15  1948.0        John F. Kennedy    Richard Nixon          Democrat
# 16  1952.0   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 17  1956.0   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 18  1960.0        Harry S. Truman  Thomas E. Dewey          Democrat
# 19  1964.0  Franklin D. Roosevelt  Thomas E. Dewey          Democrat
# 20  1968.0  Franklin D. Roosevelt  Wendell Willkie          Democrat
# 21  1972.0  Franklin D. Roosevelt       Alf Landon          Democrat
# 22  1976.0  Franklin D. Roosevelt   Herbert Hoover          Democrat
#
#    Candidate 2 Party  Electoral Votes Candidate 1  \
# 11        Republican                          297
# 12          Democrat                          520
# 13          Democrat                          301
# 14        Republican                          486
# 15        Republican                          303
# 16          Democrat                          457
# 17          Democrat                          442
# 18        Republican                          303
# 19        Republican                          432
# 20        Republican                          449
# 21        Republican                          523
# 22        Republican                          472
#
#     Electoral Votes Candidate 2 Total Votes Candidate 1  \
# 11                          240              40,831,881
# 12                           17              47,168,710
# 13                          191              31,783,783
# 14                           52              43,127,041
# 15                          219              34,220,984
# 16                           73              35,579,180
# 17                           89              34,075,529
# 18                          189              24,179,347
# 19                           99              25,612,916
# 20                           82              27,313,945
# 21                            8              27,752,648
# 22                           59              22,821,277
#
#    Total Votes Candidate 2  Inflation Rate  GDP % Growth  Unemployment Rate  \
# 11              39,148,634           -10.3         -12.9               23.6
# 12              17,995,488             1.4          12.9               16.9
# 13                 511,944             0.7           8.8               14.6
# 14              17,951,287             2.3           8.0                1.2
# 15                 112,827             3.0           4.1                4.0
# 16               9,551,152             0.8           4.1                2.7
# 17               6,700,439             3.0           2.1                4.2
# 18               2,188,055             1.4           2.6                6.6
# 19               3,594,987             1.0           5.8                5.0
# 20               4,966,201             4.7           4.9                3.4
# 21              11,070,786             3.4           5.3                5.2
# 22               7,060,023             4.9           5.4                7.8
#
#     Change Unemployment Rate Adjusted Oil Prices ($/barrel)  Change in S&P  \
# 11                     48.43                         $24.03         -15.15
# 12                    -15.92                         $24.03          27.92
# 13                    -15.12                         $24.03         -15.29
# 14                    -36.84                         $24.03          13.80
# 15                     11.11                         $33.69          -0.65
# 16                    -12.90                         $30.50          11.78
# 17                      0.00                         $31.64           2.62
# 18                     24.53                         $28.79          -2.97
# 19                     -9.09                         $28.27          12.97
# 20                    -10.53                         $26.68           7.66
# 21                    -13.33                         $25.17          15.63
# 22                     -4.88                         $67.30          19.15
#
#     June Gallup
# 11         60.0
# 12         60.0
# 13         60.0
# 14         60.0
# 15         60.0
# 16         31.5
# 17         72.0
# 18         59.0
# 19         74.0
# 20         41.0
# 21         57.5
# 22         45.0

# %%
president_df = president_df.reset_index(drop=True)
economic_df = economic_df.reset_index(drop=True)
votes = []
for x in range(len(president_df)):
    votes.append(int(president_df.iloc[[x]]["Total Votes Candidate 1"][x].replace(",", "")) + int(president_df.iloc[[x]]["Total Votes Candidate 2"][x].replace(",", "")))

president_df["Total Votes"] = votes

# %%
percentages = []
percentages2 = []

for x in range(len(president_df)):
    
    percentages.append(int(president_df.iloc[[x]]["Total Votes Candidate 1"][x].replace(",", ""))/int(president_df.iloc[[x]]["Total Votes"][x]))
    percentages2.append(int(president_df.iloc[[x]]["Total Votes Candidate 2"][x].replace(",", ""))/int(president_df.iloc[[x]]["Total Votes"][x]))

# %%
winners = []
winners.append(president_df.iloc[[0]]["Candidate 2 Party"][0])

for x in range(len(president_df)-1):
    
    winningparty = president_df.iloc[[x]]["Candidate 1 Party"][x]
    winners.append(winningparty)

# %%
winners
# Out:
# ['Republican',
#  'Democrat',
#  'Republican',
#  'Republican',
#  'Democrat',
#  'Democrat',
#  'Republican',
#  'Republican',
#  'Democrat',
#  'Democrat',
#  'Democrat',
#  'Democrat']

# %%
president_df["Candidate 1 Percentage"] = percentages
president_df["Candidate 2 Percentage"] = percentages2

# %%
president_df["IncumbentParty"] = winners

incumbent_per = []
incumbent_per.append(president_df.iloc[[0]]["Candidate 2 Percentage"][0])
for i in range(1, len(president_df)):
    if (president_df.iloc[[i]]["Candidate 1 Party"][i] == president_df.iloc[[i]]["IncumbentParty"][i]):
        incumbent_per.append(president_df.iloc[[i]]["Candidate 1 Percentage"][i])
    elif (president_df.iloc[[i]]["Candidate 2 Party"][i] == president_df.iloc[[i]]["IncumbentParty"][i]):
        incumbent_per.append(president_df.iloc[[i]]["Candidate 2 Percentage"][i])
    

president_df["IncumbentPartyPercentage"] = incumbent_per

# %%
economic_df = economic_df.reset_index(drop=True)
#for i in range(len(economic_df)):
    #year = economic_df.iloc[[i]]["Year"][i]
    
    #if(year%4 != 0):
        #print(year)
        #economic_df=economic_df.drop(economic_df.index[i])
        
        
economic_df = economic_df[economic_df['Year']%4==0]
economic_df
# Out:
#       Year  Inflation Rate  Change Federal Funds Rate  Federal Funds Rate  \
# 0   1932.0           -10.3                       0.00                0.00
# 1   1936.0             1.4                       0.00                0.00
# 2   1940.0             0.7                       0.00                0.00
# 3   1944.0             2.3                       0.00                0.00
# 4   1948.0             3.0                       0.00                0.00
# 5   1952.0             0.8                       0.00                0.00
# 6   1956.0             3.0                      20.00                3.00
# 7   1960.0             1.4                     -50.00                2.00
# 8   1964.0             1.0                       7.14                3.75
# 9   1968.0             4.7                      33.33                6.00
# 10  1972.0             3.4                      15.00                5.75
# 11  1976.0             4.9                       0.00                4.75
#
#     GDP % Growth  Unemployment Rate  Change Unemployment Rate  \
# 0          -12.9               23.6                     48.43
# 1           12.9               16.9                    -15.92
# 2            8.8               14.6                    -15.12
# 3            8.0                1.2                    -36.84
# 4            4.1                4.0                     11.11
# 5            4.1                2.7                    -12.90
# 6            2.1                4.2                      0.00
# 7            2.6                6.6                     24.53
# 8            5.8                5.0                     -9.09
# 9            4.9                3.4                    -10.53
# 10           5.3                5.2                    -13.33
# 11           5.4                7.8                     -4.88
#
#    Adjusted Oil Prices ($/barrel)  Change in Oil  Change in S&P  \
# 0                          $24.03            0.0         -15.15
# 1                          $24.03            0.0          27.92
# 2                          $24.03            0.0         -15.29
# 3                          $24.03            0.0          13.80
# 4                          $33.69           19.0          -0.65
# 5                          $30.50           -2.0          11.78
# 6                          $31.64           -1.0           2.62
# 7                          $28.79           -4.0          -2.97
# 8                          $28.27            2.0          12.97
# 9                          $26.68           -2.0           7.66
# 10                         $25.17           -3.0          15.63
# 11                         $67.30            2.0          19.15
#
#     Change in Balance of Trade  June Gallup
# 0                          0.0         60.0
# 1                          0.0         60.0
# 2                          0.0         60.0
# 3                          0.0         60.0
# 4                          0.0         60.0
# 5                          0.0         31.5
# 6                          0.0         72.0
# 7                          0.0         59.0
# 8                          0.0         74.0
# 9                          0.0         41.0
# 10                         0.0         57.5
# 11                       -89.0         45.0

# %%
president_df
# Out:
#       Year            Candidate 1      Candidate 2 Candidate 1 Party  \
# 0   1932.0           Jimmy Carter      Gerald Ford          Democrat
# 1   1936.0          Richard Nixon  George McGovern        Republican
# 2   1940.0          Richard Nixon  Hubert Humphrey        Republican
# 3   1944.0      Lyndon B. Johnson  Barry Goldwater          Democrat
# 4   1948.0        John F. Kennedy    Richard Nixon          Democrat
# 5   1952.0   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 6   1956.0   Dwight D. Eisenhower  Adlai Stevenson        Republican
# 7   1960.0        Harry S. Truman  Thomas E. Dewey          Democrat
# 8   1964.0  Franklin D. Roosevelt  Thomas E. Dewey          Democrat
# 9   1968.0  Franklin D. Roosevelt  Wendell Willkie          Democrat
# 10  1972.0  Franklin D. Roosevelt       Alf Landon          Democrat
# 11  1976.0  Franklin D. Roosevelt   Herbert Hoover          Democrat
#
#    Candidate 2 Party  Electoral Votes Candidate 1  \
# 0         Republican                          297
# 1           Democrat                          520
# 2           Democrat                          301
# 3         Republican                          486
# 4         Republican                          303
# 5           Democrat                          457
# 6           Democrat                          442
# 7         Republican                          303
# 8         Republican                          432
# 9         Republican                          449
# 10        Republican                          523
# 11        Republican                          472
#
#     Electoral Votes Candidate 2 Total Votes Candidate 1  \
# 0                           240              40,831,881
# 1                            17              47,168,710
# 2                           191              31,783,783
# 3                            52              43,127,041
# 4                           219              34,220,984
# 5                            73              35,579,180
# 6                            89              34,075,529
# 7                           189              24,179,347
# 8                            99              25,612,916
# 9                            82              27,313,945
# 10                            8              27,752,648
# 11                           59              22,821,277
#
#    Total Votes Candidate 2  Inflation Rate  ...  Unemployment Rate  \
# 0               39,148,634           -10.3  ...               23.6
# 1               17,995,488             1.4  ...               16.9
# 2                  511,944             0.7  ...               14.6
# 3               17,951,287             2.3  ...                1.2
# 4                  112,827             3.0  ...                4.0
# 5                9,551,152             0.8  ...                2.7
# 6                6,700,439             3.0  ...                4.2
# 7                2,188,055             1.4  ...                6.6
# 8                3,594,987             1.0  ...                5.0
# 9                4,966,201             4.7  ...                3.4
# 10              11,070,786             3.4  ...                5.2
# 11               7,060,023             4.9  ...                7.8
#
#     Change Unemployment Rate  Adjusted Oil Prices ($/barrel) Change in S&P  \
# 0                      48.43                          $24.03        -15.15
# 1                     -15.92                          $24.03         27.92
# 2                     -15.12                          $24.03        -15.29
# 3                     -36.84                          $24.03         13.80
# 4                      11.11                          $33.69         -0.65
# 5                     -12.90                          $30.50         11.78
# 6                       0.00                          $31.64          2.62
# 7                      24.53                          $28.79         -2.97
# 8                      -9.09                          $28.27         12.97
# 9                     -10.53                          $26.68          7.66
# 10                    -13.33                          $25.17         15.63
# 11                     -4.88                          $67.30         19.15
#
#     June Gallup  Total Votes  Candidate 1 Percentage  Candidate 2 Percentage  \
# 0          60.0     79980515                0.510523                0.489477
# 1          60.0     65164198                0.723844                0.276156
# 2          60.0     32295727                0.984148                0.015852
# 3          60.0     61078328                0.706094                0.293906
# 4          60.0     34333811                0.996714                0.003286
# 5          31.5     45130332                0.788365                0.211635
# 6          72.0     40775968                0.835677                0.164323
# 7          59.0     26367402                0.917017                0.082983
# 8          74.0     29207903                0.876917                0.123083
# 9          41.0     32280146                0.846153                0.153847
# 10         57.5     38823434                0.714843                0.285157
# 11         45.0     29881300                0.763731                0.236269
#
#     IncumbentParty IncumbentPartyPercentage
# 0       Republican                 0.489477
# 1         Democrat                 0.276156
# 2       Republican                 0.984148
# 3       Republican                 0.293906
# 4         Democrat                 0.996714
# 5         Democrat                 0.211635
# 6       Republican                 0.835677
# 7       Republican                 0.082983
# 8         Democrat                 0.876917
# 9         Democrat                 0.846153
# 10        Democrat                 0.714843
# 11        Democrat                 0.763731
#
# [12 rows x 21 columns]

# %%
#june_gallup = [60,60,60,60,60,31.5,72,59,74,41,57.5,45.0, 33.6, 54.0, 50.0, 37.3, 55.0, 57.5, 48.5, 29.0, 46.4, 51.6, 38]
june_gallup = [45.0, 33.6, 54.0, 50.0, 37.3, 55.0, 57.5, 48.5, 29.0, 46.4, 51.6, 38]

economic_df['June Gallup'] = june_gallup

# %%
for column in economic_df:
    president_df[column] = economic_df[column].tolist()

# %%
economic_df['Incumbent Percentage'] = president_df['IncumbentPartyPercentage'].tolist()

# %%
sns.heatmap(economic_df.corr())
# Out:
# <AxesSubplot:>

# %%
economic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            12 non-null     float64
#  1   Inflation Rate                  12 non-null     float64
#  2   Change Federal Funds Rate       12 non-null     float64
#  3   Federal Funds Rate              12 non-null     float64
#  4   GDP % Growth                    12 non-null     float64
#  5   Unemployment Rate               12 non-null     float64
#  6   Change Unemployment Rate        12 non-null     float64
#  7   Adjusted Oil Prices ($/barrel)  12 non-null     object
#  8   Change in Oil                   12 non-null     float64
#  9   Change in S&P                   12 non-null     float64
#  10  Change in Balance of Trade      12 non-null     float64
#  11  June Gallup                     12 non-null     float64
#  12  Incumbent Percentage            12 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 1.3+ KB

# %%
plt.scatter(economic_df['GDP % Growth'], economic_df['Incumbent Percentage'])
plt.xlabel('GDP % Growth')
plt.ylabel('Incumbent Popular Vote %')
plt.show()
plt.scatter(economic_df['Change in S&P'], economic_df['Incumbent Percentage'])
plt.xlabel('Change in S&P')
plt.ylabel('Incumbent Popular Vote %')
plt.show()

plt.scatter(economic_df['June Gallup'], economic_df['Incumbent Percentage'])
plt.xlabel('June Gallup')
plt.ylabel('Incumbent Popular Vote %')
plt.show()

plt.scatter(economic_df['Change Unemployment Rate'], economic_df['Incumbent Percentage'])
plt.xlabel('Change Unemployment Rate')
plt.ylabel('Incumbent Popular Vote %')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

# %%
k = [1,2,3,4,5]
from sklearn.metrics import r2_score


def best_poly(X, Y, k):
    '''
    Compute the best fit polynomial to (X,Y) of degree k
    and the mean squared error.
    Inputs:
        X: a numpy array of the dependent variables
        Y: a numpy array of the independent variables
        k: the degree of the fitted polynomial
    Outputs: 
        p: the coefficients of the best fit polynomial, 
            in decreasing order of power
        mse: the mean squared error
    '''
    
    # your code here..
    
    #using np.polyfit.
    fit = np.polyfit(X,Y,k,full=True)
 
    
    #calculating coeffcieints
    p = fit[0]
   
    #calculating mse
    mse = (fit[1]) / len(Y)

    #returning both
    return p, mse


def plot_poly_with_data(X, Y, k, plot_title):
    '''
    Plot the best fit polynomial to X, Y of degree k,
    as well as the points X and Y
    Inputs:
        X: a numpy array of the dependent variables
        Y: a numpy array of the independent variables
        k: the degree of the fitted polynomial
        plot_title: title of your plot, supplied as a string
    Outputs:
        Nothing, just display the plot.
    '''
    #What does p, _ mean? What is the line?
    p, mse = best_poly(X,Y,k) # compute the coefficients for the best polynomial
    #extract coefficients from p
    coefficients = np.poly1d(p)
    #points on the poly line of best fit
    plt.plot(np.linspace(-40, 30, num = len(economic_df['June Gallup'])), coefficients(np.linspace(-40, 30, num=len(economic_df['GDP % Growth']))), color = "red")
    plt.title(plot_title)
   
    print("R2: ")
    print(r2_score(economic_df['Incumbent Percentage'], coefficients(economic_df['GDP % Growth'])))
    plt.scatter(X, y=Y, color="green")


for element in k:
    plot_poly_with_data(economic_df['GDP % Growth'], economic_df['Incumbent Percentage'], element, "Degree: " + str(element))
    plt.xlabel('GDP % Growthe')
    plt.ylabel('Incumbent Party % Votes')
    plt.show()
# Out:
# R2:
# 0.0018075130451384869
# R2:
# 0.060483870104698134
# R2:
# 0.17922666721455704
# R2:
# 0.17952707094033282
# R2:
# 0.18574719070880408

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

X_train, X_test, y_train, y_test = train_test_split(economic_df[['GDP % Growth', 'June Gallup', 'Change Federal Funds Rate', 'Change in Balance of Trade']], y, test_size=0.3)

y_train = y_train > 0.5
y_test = y_test > 0.5


decision_tree = DecisionTreeClassifier(criterion='gini')
decision_tree = decision_tree.fit(X_train, y_train)

print("Training Accuracy:",metrics.accuracy_score(y_train, decision_tree.predict(X_train)))
print("Testing Accuracy:",metrics.accuracy_score(y_test, decision_tree.predict(X_test)))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.25

# %%
from sklearn import tree

tree.plot_tree(decision_tree)
# Out:
# [Text(0.5, 0.8333333333333334, 'X[1] <= 46.75\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.25, 0.5, 'X[0] <= 9.35\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.5, 'X[0] <= 8.4\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5

# %%
accuracies = []
for i in range (1, 16):
    clf=RandomForestClassifier(n_estimators=i)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    accuracies.append(metrics.accuracy_score(y_test, y_pred))

plt.plot(np.arange(1,16), accuracies)
plt.xlabel('Number of Trees')
plt.ylabel('Accuracy of Random Forest')
# Out:
# Text(0, 0.5, 'Accuracy of Random Forest')
